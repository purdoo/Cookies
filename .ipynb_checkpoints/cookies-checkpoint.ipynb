# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/cookie_ratings.csv',index_col=0)
# df.fillna('', inplace=True)
# Isolate cookie columns
cookie_cols = df.columns

# %%
# Cookie rankings dict
cookie_ratings = {} # Key: Cookie, Val: (mean, std, # ratings)
for col in df.columns:
    cookie_ratings[col] = (df[col].mean(),df[col].std(), df[col].count())
cookie_ratings
# Out:
# {'Do-si-do': (6.46875, 2.232104761579677, 16),
#  "S'mores": (5.583333333333333, 1.6213537179739277, 12),
#  'Samoas': (7.476190476190476, 2.2219146612560894, 21),
#  'Savannah Smile': (6.25, 2.3918933601132486, 14),
#  'Tagalong': (6.3, 2.0160073696010428, 15),
#  'Thin Mint': (7.323529411764706, 1.7848422240371506, 17),
#  'Toffee-tastic': (5.055555555555555, 1.7977836754712315, 18),
#  'Trefoil': (5.882352941176471, 1.6912404079985375, 17)}

# %%
# Plotting Cookie Rankings
import matplotlib.pyplot as plt

df.boxplot(showfliers=False,showmeans=True,figsize=(16,7),grid=False,patch_artist=True)

# %%
# Adding 'User Average' and 'Rating Count' cols
df['User Average'] = df[cookie_cols].mean(axis=1)
df['Rating Count'] = df[cookie_cols].notna().sum(axis=1)
df
# Out:
#            Savannah Smile  Thin Mint  Do-si-do  Trefoil  Toffee-tastic  \
# Name
# Chris                 6.5        6.0       7.5      7.0            5.0
# Colleen               8.0        9.0       6.0      5.0            5.0
# Derek                 6.0        9.0       6.0      5.0            3.0
# Kevin                 7.0        4.0       NaN      8.0            6.0
# Vi                    NaN        NaN       NaN      NaN            5.0
# Shashin               NaN        NaN       NaN      NaN            7.0
# Maggie                6.0        NaN       NaN      NaN            6.0
# Brandon               7.0        NaN       NaN      NaN            5.0
# Amanda                7.0        NaN       NaN      NaN            3.0
# Roman*               10.0        4.0       1.0      6.0            6.0
# Jeff                  1.0        7.0       7.0      3.0            3.0
# Phteven               5.0       10.0       9.0      5.0            5.0
# Lara                  2.0        5.0      10.0      2.0            2.0
# Tom D                 NaN        8.0       9.0      6.0            NaN
# Nobis                 9.0        7.0       8.0      7.0            8.0
# Emily                 NaN        7.0       8.0      7.0            8.0
# Varun                 NaN        9.0       5.0      5.0            7.0
# Araba                 6.0        6.5       5.0      8.0            4.0
# Jon Park              NaN        8.0       7.0      7.0            NaN
# Charlotte             7.0        9.0       5.0      6.0            3.0
# Justin                NaN        8.5       6.0      8.0            NaN
# Dan                   NaN        7.5       4.0      5.0            NaN
#
#            Tagalong  Samoas  S'mores  User Average  Rating Count
# Name
# Chris           8.0     9.0      7.0      7.000000             8
# Colleen         7.0     8.5      5.0      6.687500             8
# Derek           8.0     9.0      5.0      6.375000             8
# Kevin           NaN     9.0      NaN      6.800000             5
# Vi              NaN     NaN      6.0      5.500000             2
# Shashin         NaN     9.0      NaN      8.000000             2
# Maggie          NaN     8.0      NaN      6.666667             3
# Brandon         8.0     6.0      8.0      6.800000             5
# Amanda          NaN     9.0      NaN      6.333333             3
# Roman*          4.0     9.0      4.0      5.500000             8
# Jeff            8.0     7.0      4.0      5.000000             8
# Phteven         5.0     5.0      5.0      6.125000             8
# Lara            5.0     6.0      8.0      5.000000             8
# Tom D          10.0     2.0      7.0      7.000000             6
# Nobis           3.0     2.0      NaN      6.285714             7
# Emily           NaN     8.0      NaN      7.600000             5
# Varun           6.0     9.0      NaN      6.833333             6
# Araba           4.5     9.0      3.0      5.750000             8
# Jon Park        6.0     8.5      NaN      7.300000             5
# Charlotte       8.0     9.0      5.0      6.500000             8
# Justin          NaN     9.0      NaN      7.875000             4
# Dan             4.0     6.0      NaN      5.300000             5
